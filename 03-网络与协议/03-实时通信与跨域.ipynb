# %% [markdown]
# # 实时通信与跨域

# %% [markdown]
# ## 长轮询
#
# 服务器把请求挂住，等真的有消息了再响应。

# %% [markdown]
# ## WebSocket
#
# WebSocket 让借 HTTP 完成握手浏览器和服务器之间建立一条持久的、双向的通信通道。

# %% [markdown]
# ## SSE
#
# SSE 服务器可以持续推送数据给浏览器。

# %% [markdown]
# ## 同源策略 CORS
#
# 协议、域名、端口全一样，才能访问
