# %% [markdown]
# # 客户端、服务器、DNS、IP与传输连接

# %% [markdown]
# ## 客户端
#
# 主动请求服务的一方。

# %% [markdown]
# ## 服务器是什么
#
# 提供服务的一端：第一层是硬件或云资源，比如一台云服务器。第二层是运行在机器上的服务程序。

# %% [markdown]
# ## DNS
#
# 把域名解析成 IP 地址。

# %% [markdown]
# ## 端口
#
# 端口，英文是 port，用来区分同一台机器上的不同服务。

# %% [markdown]
# ## TCP 是什么
#
# 一种可靠传输协议

# %% [markdown]
# ## UDP 是什么
#
# 更轻量的不可靠传输协议
