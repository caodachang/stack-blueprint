# %% [markdown]
# # 进程守护、云服务与部署运行环境

# %% [markdown]
# ## 进程守护
#
# 进程守护是让程序在服务器上长期稳定运行的机制，由管理工具实现。
#
# systemd 是很多 Linux 发行版默认的系统和服务管理工具。
#
# PM2 是 Node.js 生态里常见的进程管理工具。
#
# Supervisor 是通用的进程管理工具，常用于管理 Python、脚本任务或其他长期运行进程

# %% [markdown]
# ## 云服务器
#
# 云服务器是云厂商提供的虚拟服务器。
#
# VPC 是云上的私有网络
#
# IAM 是身份与访问管理。
