# %% [markdown]
# # 互联网是怎么工作的

# %% [markdown]
# ## DNS 域名解析系统
# ## 端口找到服务器上的具体服务
#
# | 默认端口 | 服务 |
# |------|------|
# | `80` | HTTP |
# | `443` | HTTPS |
# | `22` | ssh |
#
# 访问普通端口时需要写端口号 `ws://127.0.0.1:8080` （WebSocket，网页实时通信）
#
# `url` : 统一资源定位符 ( 协议 + 服务器地址 + 端口 + 文件位置 )
